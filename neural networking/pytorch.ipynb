# %%
import torch

a = torch.tensor([1, 2, 3])
b = torch.tensor([1, 2, 3], dtype=torch.float32)

print(a.dtype)
print(b.dtype)
# Out:
# torch.int64
# torch.float32

# %%
a = torch.tensor([2.0, 3.0], requires_grad=True)
print(a)
# Out:
# tensor([2., 3.], requires_grad=True)

# %%
x = torch.tensor([2.0], requires_grad=True)
y = x ** 2  # y = x squared

y.backward()  # calculate gradient
print(x.grad)
# Out:
# tensor([4.])

# %%
    

import torch.nn as nn


model.eval()  # switch to evaluation mode

with torch.no_grad():  # no gradient tracking needed
    y_pred = model(X_test)
    y_pred_labels = (y_pred.squeeze() > 0.5).float()
    
    accuracy = (y_pred_labels == y_test).float().mean()
    print(f"Accuracy: {accuracy.item() * 100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4
#       1 from xml.parsers.expat import model
#       2
#       3
# ----> 4 model.eval()  # switch to evaluation mode
#       5
#       6 with torch.no_grad():  # no gradient tracking needed
#       7     y_pred = model(X_test)
#
# AttributeError: module 'pyexpat.model' has no attribute 'eval'
