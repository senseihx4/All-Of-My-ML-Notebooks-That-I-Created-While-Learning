# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# Open browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Open a website
driver.get("https://the-internet.herokuapp.com/login")

print(driver.title)
# Out:
# The Internet

# %%
driver.get("https://the-internet.herokuapp.com/login")
time.sleep(2)

username = driver.find_element(By.ID, "username")
username.send_keys("tomsmith")

password = driver.find_element(By.ID, "password")
password.send_keys("SuperSecretPassword!")

# Click login button
button = driver.find_element(By.CSS_SELECTOR, "button[type='submit']")
button.click()

time.sleep(2)
print(driver.title)
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[6], line 10
#       6 username.send_keys(Keys.RETURN)
#       7
#       8
#       9 password = driver.find_element(By.ID, "password")
# ---> 10 password.send_keys("SuperSecretPassword!")
#
# File ~/Desktop/Local Projects/Machiene learning/venv/lib/python3.14/site-packages/selenium/webdriver/remote/webelement.py:276, in WebElement.send_keys(self, *value)
#     273             remote_files.append(self._upload(file))
#     274         value = tuple("\n".join(remote_files))
# --> 276 self._execute(
#     277     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     278 )
#
# File ~/Desktop/Local Projects/Machiene learning/venv/lib/python3.14/site-packages/selenium/webdriver/remote/webelement.py:508, in WebElement._execute(self, command, params)
#     506     params = {}
#     507 params["id"] = self._id
# --> 508 return self._parent.execute(command, params)
#
# File ~/Desktop/Local Projects/Machiene learning/venv/lib/python3.14/site-packages/selenium/webdriver/remote/webdriver.py:468, in WebDriver.execute(self, driver_command, params)
#     465 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     467 if response:
# --> 468     self.error_handler.check_response(response)
#     469     response["value"] = self._unwrap_value(response.get("value", None))
#     470     return response
#
# File ~/Desktop/Local Projects/Machiene learning/venv/lib/python3.14/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)
# --> 232 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=148.0.7778.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementnotinteractableexception
# Stacktrace:
# 0   chromedriver                        0x0000000104cb4c40 cxxbridge1$str$ptr + 3221216
# 1   chromedriver                        0x0000000104cacb1c cxxbridge1$str$ptr + 3188156
# 2   chromedriver                        0x000000010476f6f8 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 74644
# 3   chromedriver                        0x00000001047b427c _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 356120
# 4   chromedriver                        0x00000001047b2bb0 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 350284
# 5   chromedriver                        0x00000001047aeec4 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 334688
# 6   chromedriver                        0x00000001047f76f4 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 631696
# 7   chromedriver                        0x00000001047ad9c0 _RNvCsiKAbIcglKMQ_7___rustc35___rust_no_alloc_shim_is_unstable_v2 + 329308
# 8   chromedriver                        0x0000000104c72b70 cxxbridge1$str$ptr + 2950672
# 9   chromedriver                        0x0000000104c762c8 cxxbridge1$str$ptr + 2964840
# 10  chromedriver                        0x0000000104c578a8 cxxbridge1$str$ptr + 2839368
# 11  chromedriver                        0x0000000104c76b48 cxxbridge1$str$ptr + 2967016
# 12  chromedriver                        0x0000000104c483d4 cxxbridge1$str$ptr + 2776692
# 13  chromedriver                        0x0000000104c9b7ac cxxbridge1$str$ptr + 3117644
# 14  chromedriver                        0x0000000104c9b90c cxxbridge1$str$ptr + 3117996
# 15  chromedriver                        0x0000000104cac774 cxxbridge1$str$ptr + 3187220
# 16  libsystem_pthread.dylib             0x000000018815dc58 _pthread_start + 136
# 17  libsystem_pthread.dylib             0x0000000188158c1c thread_start + 8
